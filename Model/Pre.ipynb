# %%
# Cell 2
# Nếu đọc từ file csv thì dùng dòng dưới, nếu đã có df thì bỏ qua dòng này
# df = pd.read_csv('your_data.csv') 

# Xem 5 dòng đầu
display(df.head())

# Kiểm tra kiểu dữ liệu và số lượng giá trị thiếu (Null)
print("\n--- Info ---")
print(df.info())

print("\n--- Số lượng giá trị Null trên mỗi cột ---")
print(df.isnull().sum())
